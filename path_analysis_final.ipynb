# %%
import src.main as main

# %%
algos = main.pathPlanningAnalysis()
# Out:
# Running BFS on ./src/maps/map1.txt
# Execution Time: 0.0002987384796142578 seconds
# Visited states count: 78
# Execution Time: 0.0002079010009765625 seconds
# Visited states count: 62
# Execution Time: 0.0002682209014892578 seconds
# Visited states count: 77
# Running BFS on ./src/maps/map2.txt
# Execution Time: 0.0006587505340576172 seconds
# Visited states count: 173
# Execution Time: 0.0005059242248535156 seconds
# Visited states count: 141
# Execution Time: 0.0005650520324707031 seconds
# Visited states count: 158
# Running BFS on ./src/maps/map3.txt
# Execution Time: 0.002819538116455078 seconds
# Visited states count: 735
# Execution Time: 0.002317667007446289 seconds
# Visited states count: 508
# Execution Time: 0.00041937828063964844 seconds
# Visited states count: 112
# Running BFS on ./src/maps/map4.txt
# Execution Time: 0.012837886810302734 seconds
# Visited states count: 2991
# Execution Time: 0.011791229248046875 seconds
# Visited states count: 2784
# ...

# %%
main.plot_metrics(algos,"execution_times","Goal #","Time (s)","Execution Time")

# %%
main.plot_metrics(algos,"visited_states_count","Goal #","Visited States Count","# of States Visited")

# %%
main.plot_metrics(algos,"path_length","Goal #","Path Length","Length of Path")
